# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from scipy import stats
from scipy.stats import norm

# %% [markdown]
# ### Topics: Normal distribution, Functions of Random Variables

# %%
1-stats.norm.cdf(60, 55, 8)
# Out:
# 0.26598552904870054

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# https://www.scribbr.com/statistics/normal-distribution/

# %%
#q2_lessthan_38
1-stats.norm.cdf(38, 38, 6)
# Out:
# 0.5

# %%
#q2_lessthan_44
stats.norm.cdf(44, 38, 6)
# Out:
# 0.8413447460685429

# %%
#q2_betweeen_38_and_44
0.8413447460685429-0.5
# Out:
# 0.3413447460685429

# %%
#q2_morethan_44
1-stats.norm.cdf(44, 38, 6)
# Out:
# 0.15865525393145707

# %% [markdown]
# False. Because the probability for employees at the processing center are more between 38 and 44 than older than 44. mean = 38 std1 = 6 q2_lessthan_38 = stats.norm.cdf(38, loc = mean, scale = std1) q2_lessthan_38 = 0.5 q2_less_than_44 = stats.norm.cdf(44, loc = mean, scale = std1) q2_less_than_44 = 0.841 q2_betweeen_38_and_44 = q2_less_than_44 - q2_lessthan_38 print('The probability of employee age between 38 and 44 is',np.round(q2_betweeen_38_and_44100,2),'%') The probability of employee age between 38 and 44 is 34.13 % q2_morethan_44 = 1-stats.norm.cdf(44, loc = mean, scale = std1) print('The probability of employee age more than 44 is',np.round(q2_morethan_44100,2),'%') The probability of employee age more than 44 is 15.87 % true_or_false = (q2_morethan_44 > q2_betweeen_38_and_44) print('Answer:',true_or_false)

# %%
# P(X<30); Employees under 30 yrs of age
stats.norm.cdf(30,38,6)
# Out:
# 0.09121121972586788

# %%
# No. of employees attending training program from 400 nos. is N*P(X<30)
nemp = 400*stats.norm.cdf(30,38,6)
nemp
# Out:
# 36.484487890347154

# %%
print('A training program for employees under the age of 30 at the center would be expected to attract about',nemp,'employees')
# Out:
# A training program for employees under the age of 30 at the center would be expected to attract about 36.484487890347154 employees

# %% [markdown]
# As we know that if  X ∼ N(µ1, σ1^2 ), and  Y ∼ N(µ2, σ2^2 ) are two independent  random variables then   X + Y ∼ N(µ1 + µ2, σ1^2 + σ2^2 ) , and      X − Y ∼ N(µ1 − µ2, σ1^2 + σ2^2 ) .
# Similarly if  Z = aX + bY , where X and Y are as defined above, i.e Z is linear combination of X and Y , then Z ∼ N(aµ1 + bµ2, a^2σ1^2 + b^2σ2^2 ).
# Therefore in the question
# 2X1~ N(2 u,4 σ^2) and X1+X2 ~  N(µ + µ, σ^2 + σ^2 ) ~ N(2 u, 2σ^2 )
# 2X1-(X1+X2) = N( 4µ,6 σ^2)

# %%
pxyval = stats.norm.interval(0.99, loc = 100, scale = 20)

# %%
print('The two values of a and b, symmetric about the mean, are such that the probability of the random variable taking a value between them is 0.99:',pxyval)
# Out:
# The two values of a and b, symmetric about the mean, are such that the probability of the random variable taking a value between them is 0.99: (48.48341392902199, 151.516586070978)

# %% [markdown]
# ## Q5 (Basic Statistic Level-2)

# %%
# Mean profits from two different divisions of a company = Mean1 + Mean2
Mean = 5+7
print('Mean Profit is Rs', Mean*45,'Million')
# Out:
# Mean Profit is Rs 540 Million

# %%
# Variance of profits from two different divisions of a company = SD^2 = SD1^2 + SD2^2
SD = np.sqrt((9)+(16))
print('Standard Deviation is Rs', SD*45, 'Million')
# Out:
# Standard Deviation is Rs 225.0 Million

# %%
# A. Specify a Rupee range (centered on the mean) such that it contains 95% probability for the annual profit of the company.
print('Range is Rs',(stats.norm.interval(0.95,540,225)),'in Millions')
# Out:
# Range is Rs (99.00810347848784, 980.9918965215122) in Millions

# %%
# B. Specify the 5th percentile of profit (in Rupees) for the company
# To compute 5th Percentile, we use the formula X=μ + Zσ; wherein from z table, 5 percentile = -1.645
X= 540+(-1.645)*(225)
print('5th percentile of profit (in Million Rupees) is',np.round(X,))
# Out:
# 5th percentile of profit (in Million Rupees) is 170.0

# %%
# C. Which of the two divisions has a larger probability of making a loss in a given year?

# %%
# Probability of Division 1 making a loss P(X<0)
stats.norm.cdf(0,5,3)
# Out:
# 0.0477903522728147

# %%
# Probability of Division 2 making a loss P(X<0)
stats.norm.cdf(0,7,4)
# Out:
# 0.040059156863817086

# %% [markdown]
# ## Topics: Descriptive Statistics and Probability

# %% [markdown]
# ### Q1

# %%
# initialize list of lists
data = {'Name of company': ["Allied Signal","Bankers Trust","General Mills","ITT Industries","J.P.Morgan & Co.","Lehman Brothers","Marriott","MCI","Merrill Lynch","Microsoft","Morgan Stanley","Sun Microsystems","Travelers","US Airways","Warner-Lambert"], 'Measure X':[24.23,25.53,25.41,24.14,29.62,28.25,25.81,24.39,40.26,32.95,91.36,25.99,39.42,26.71,35.00]}
# Create the pandas DataFrame
df = pd.DataFrame(data)
df
# Out:
#      Name of company  Measure X
# 0      Allied Signal      24.23
# 1      Bankers Trust      25.53
# 2      General Mills      25.41
# 3     ITT Industries      24.14
# 4   J.P.Morgan & Co.      29.62
# 5    Lehman Brothers      28.25
# 6           Marriott      25.81
# 7                MCI      24.39
# 8      Merrill Lynch      40.26
# 9          Microsoft      32.95
# 10    Morgan Stanley      91.36
# 11  Sun Microsystems      25.99
# 12         Travelers      39.42
# 13        US Airways      26.71
# 14    Warner-Lambert      35.00

# %%
df.describe()
# Out:
#        Measure X
# count  15.000000
# mean   33.271333
# std    16.945401
# min    24.140000
# 25%    25.470000
# 50%    26.710000
# 75%    33.975000
# max    91.360000

# %%
#df[Measure X]=df[Measure X].astype('int')
#df = df['Measure X'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name of company  15 non-null     object
#  1   Measure X        15 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 368.0+ bytes

# %%
#sns.boxplot(df['Measure X'])

plt.figure(figsize=(10,5))
plt.boxplot(df['Measure X'])
plt.title("Measure X")
plt.show()

# %%
df.var()
# Out:
# C:\Users\esati\AppData\Local\Temp\ipykernel_14140\1568254755.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.var()
# Measure X    287.146612
# dtype: float64

# %%
287.146612**0.5
# Out:
# 16.945400909981444

# %%
# initialize list of lists
data = {'NUmber': [0,5,7,12,19,25]}
# Create the pandas DataFrame
df3 = pd.DataFrame(data)
df3
# Out:
#    NUmber
# 0       0
# 1       5
# 2       7
# 3      12
# 4      19
# 5      25

# %%
sns.boxplot(df3['NUmber'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='NUmber'>

# %%
stats.norm.cdf(200, 5, 1)
# Out:
# 1.0

# %% [markdown]
# ## Set 3

# %% [markdown]
# ## Q5

# %%
import numpy as np
from scipy import stats
from scipy.stats import norm

# %%
# Apply One-Sample One-Tail z-test

# %%
z_scores=(0.046-0.05)/(np.sqrt((0.05*(1-0.05))/2000))
z_scores
# Out:
# -0.820782681668124

# %%
# Find Probability assuming null hyposthesis, so as to compare with Type-1 error α = 0.05

# %%
p_value=1-stats.norm.cdf(abs(z_scores))
p_value
# Out:
# 0.20588503245107104
